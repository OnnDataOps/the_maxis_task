# %% [markdown]
# # The Maxis Task

# %% [markdown]
# ### Task to do:
# 1.     Create data pipeline to ingest data from public website(airport DB: link), store data in raw form in Google Storage, and ingest the data into BigQuery for analysis purpose.
# ( link : https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat )
# 2.     Share snapshot of the codes, and provide screenshot of BigQuery showing how many airports there are in Malaysia.
#
# 3.     Material/Codes to be shared for reference. Publish in Git/Google Cloud Source Repo.

# %% [markdown]
# ### packages to install before the program

# %%
# !pip install google-cloud-storage
# !pip install google-cloud-bigquery
# !pip install pyarrow

# %% [markdown]
# ## The Airport Data Pipeline

# %% [markdown]
# ### Download raw data file from URL

# %%
from google.cloud import storage
import pandas as pd 
import requests
import io

#Download file from url
url="https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat"
file = requests.get(url)
open('C:/Users/weionn.chong/Documents/Onn/Work/R&D/maxis_task/airport.dat', 'wb').write(myfile.content)
print("File download complete")
# Out:
# File download complete

# %% [markdown]
# ### Upload raw data file to storage

# %%
#store raw data to google cloud storage
client = storage.Client.from_service_account_json('onn-research-dev-storage.json')   #initializing google storage with credentials
bucket = client.get_bucket('maxis_task')
blob = bucket.blob('airport.dat')
blob.upload_from_filename('airport.dat')
print("Upload to google storage complete")
# Out:
# Upload to google storage complete

# %% [markdown]
# ### Data Transformation

# %%
#peek the data file from url
data = pd.read_csv('airport.dat', header = None)
data.head()
# Out:
#    0                                            1             2   \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#                  3    4     5         6           7     8   9  10  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998  5282  10  U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001    20  10  U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005  5388  10  U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977   239  10  U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001   146  10  U
#
#                      11       12           13
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
print(len(data))
# Out:
# 7698

# %%
#Transformation
#Renaming the column names
data.rename(columns = {1: 'airport_name',
                       2: 'city',
                       3: 'country',
                       4: 'airport_code',
                       5: 'iso_code',
                       6: 'latitude',
                       7: 'longitude',
                       8: 'elevation',
                       9: 'timezone',
                       10: 'unknown',
                       11: 'continent/region',
                       12: 'type',
                       13: 'source'}, inplace=True)

# %%
#reset index and droping the initial index column
data = data.reset_index().drop(columns = 0)

# %% [markdown]
# ### Upload dataframe to BigQuery table

# %%
from google.cloud import bigquery
#Initialize the project id and staging table destination
table_destination_firm = 'onn-research-dev.maxis_task.airport_db'

#initializing the client with google credentials
client = bigquery.Client.from_service_account_json('onn-research-dev-bigquery.json')

#Setting the schema for the bigquery table
job_config_airport = bigquery.LoadJobConfig(scheme=[
                        bigquery.SchemaField("no", "STRING"),
                        bigquery.SchemaField("airport_name", "STRING"),
                        bigquery.SchemaField("city", "STRING"),
                        bigquery.SchemaField("country", "STRING"),
                        bigquery.SchemaField("airport_code", "STRING"),
                        bigquery.SchemaField("iso_code", "STRING"),
                        bigquery.SchemaField("latitude", "STRING"),
                        bigquery.SchemaField("longitude", "STRING"),
                        bigquery.SchemaField("elevation", "STRING"),
                        bigquery.SchemaField("timezone", "STRING"),
                        bigquery.SchemaField("Unknown", "STRING"),
                        bigquery.SchemaField("continent/region", "STRING"),
                        bigquery.SchemaField("type", "STRING"),
                        bigquery.SchemaField("source", "STRING")],
                        write_disposition="WRITE_TRUNCATE"
                    )
#passing dataframe to bigquery table
job_airport = client.load_table_from_dataframe(data, table_destination_firm, job_config=job_config_airport)

job_airport.result()
print('Upload to bigquery table is completed')

# %% [markdown]
# ## View Result (Extra)

# %% [markdown]
# ### Show all airport in Malaysia and the total number

# %%
#run sql job to query all the airports in malaysia
sql = """
    SELECT distinct *
    FROM `onn-research-dev.maxis_task.airport_db`
    WHERE country = @country
"""
query_config = bigquery.QueryJobConfig(
                    query_parameters=[
                        bigquery.ScalarQueryParameter('country','STRING','Malaysia')
                    ])

result_my = client.query(sql, job_config=query_config).to_dataframe()

display(result_my) #diplay airport details in malaysia
print(f"Total number of airport in Malaysia is {len(result_my)}")  #number of airport in malaysia
# Out:
#                                     airport_name              city   country  \
# 0                                Bintulu Airport           Bintulu  Malaysia
# 1                  Kuching International Airport           Kuching  Malaysia
# 2                                Limbang Airport           Limbang  Malaysia
# 3                                 Marudi Airport            Marudi  Malaysia
# 4                                   Miri Airport              Miri  Malaysia
# 5                                   Sibu Airport              Sibu  Malaysia
# 6                             Lahad Datu Airport        Lahad Datu  Malaysia
# 7            Kota Kinabalu International Airport     Kota Kinabalu  Malaysia
# 8                                 Labuan Airport            Labuan  Malaysia
# 9                                  Tawau Airport             Tawau  Malaysia
# 10                                Kluang Airport            Kluang  Malaysia
# 11                    Sultan Abdul Halim Airport        Alor Setar  Malaysia
# 12                           Butterworth Airport       Butterworth  Malaysia
# 13                   Sultan Ismail Petra Airport        Kota Bahru  Malaysia
# 14                               Kuantan Airport           Kuantan  Malaysia
# 15                                Kerteh Airport            Kerteh  Malaysia
# 16                               Simpang Airport           Simpang  Malaysia
# 17                     Sultan Azlan Shah Airport              Ipoh  Malaysia
# 18                   Senai International Airport       Johor Bahru  Malaysia
# 19            Kuala Lumpur International Airport      Kuala Lumpur  Malaysia
# 20                Langkawi International Airport          Langkawi  Malaysia
# 21                               Malacca Airport           Malacca  Malaysia
# 22                         Sultan Mahmud Airport  Kuala Terengganu  Malaysia
# 23                  Penang International Airport            Penang  Malaysia
# 24                          Pulau Tioman Airport            Tioman  Malaysia
# 25  Sultan Abdul Aziz Shah International Airport      Kuala Lumpur  Malaysia
# 26                      LTS Pulau Redang Airport            Redang  Malaysia
# 27                                  Mulu Airport              Mulu  Malaysia
# 28                              Sandakan Airport          Sandakan  Malaysia
# 29                                Belaga Airport            Belaga  Malaysia
# 30                          Long Lellang Airport        Long Datih  Malaysia
# 31                          Long Seridan Airport      Long Seridan  Malaysia
# 32                                 Mukah Airport             Mukah  Malaysia
# 33                             Bakalalan Airport         Bakalalan  Malaysia
# 34                                 Lawas Airport             Lawas  Malaysia
# 35                                 Bario Airport             Bario  Malaysia
# 36                            Tomanggong Airport        Tomanggong  Malaysia
# 37                                 Kudat Airport             Kudat  Malaysia
# 38                         Pulau Pangkor Airport    Pangkor Island  Malaysia
# 39                             Long Akah Airport         Long Akah  Malaysia
#
#    airport_code iso_code  latitude   longitude  elevation timezone unknown  \
# 0           BTU     WBGB   3.12385  113.019997         74        8       N
# 1           KCH     WBGG   1.48470  110.347000         89        8       N
# 2           LMN     WBGJ   4.80830  115.010002         14        8       N
# 3           MUR     WBGM   4.17898  114.329002        103        8       N
# 4           MYY     WBGR   4.32201  113.987000         59        8       N
# 5           SBW     WBGS   2.26160  111.985001        122        8       N
# 6           LDU     WBKD   5.03225  118.323997         45        8       N
# 7           BKI     WBKK   5.93721  116.051003         10        8       N
# 8           LBU     WBKL   5.30068  115.250000        101        8       N
# 9           TWU     WBKW   4.32016  118.127998         57        8       N
# 10           \N     WMAP   2.04139  103.306999        150        8       N
# 11          AOR     WMKA   6.18967  100.398003         15        8       N
# 12          BWH     WMKB   5.46592  100.390999         11        8       N
# 13          KBR     WMKC   6.16685  102.292999         16        8       N
# 14          KUA     WMKD   3.77539  103.209000         58        8       N
# 15          KTE     WMKE   4.53722  103.427002         18        8       N
# 16           \N     WMKF   3.11225  101.703003        111        8       N
# 17          IPH     WMKI   4.56797  101.092003        130        8       N
# 18          JHB     WMKJ   1.64131  103.669998        135        8       N
# 19          KUL     WMKK   2.74558  101.709999         69        8       N
# 20          LGK     WMKL   6.32973   99.728699         29        8       N
# 21          MKZ     WMKM   2.26336  102.251999         35        8       N
# 22          TGG     WMKN   5.38264  103.102997         21        8       N
# 23          PEN     WMKP   5.29714  100.277000         11        8       N
# 24          TOD     WMBT   2.81818  104.160004         15        8       N
# 25          SZB     WMSA   3.13058  101.549004         90        8       N
# 26          RDN     WMPR   5.76528  103.007004         36        8       N
# 27          MZV     WBMU   4.04833  114.805000         80        8       N
# 28          SDK     WBKS   5.90090  118.058998         46        8       N
# 29          BLG     WBGC   2.65000  113.766998        200        8       N
# 30          LGL     WBGF   3.42100  115.153999       1400        8       N
# 31          ODN     WBGI   3.96700  115.050003        607        8       N
# 32          MKM     WBGK   2.90639  112.080002         13        8       N
# 33          BKM     WBGQ   3.97400  115.617996       2900        8       N
# 34          LWY     WBGW   4.84917  115.407997          5        8       N
# 35          BBN     WBGZ   3.73389  115.478996       3350        8       N
# 36          TMG     WBKM   5.40257  118.657630         26        8       N
# 37          KUD     WBKT   6.92250  116.835999         10        8       N
# 38          PKG     WMPA   4.24472  100.553001         19        8       N
# 39          LKH     WBGL   3.30000  114.782997        289        8       N
#
#      continent_region     type       source
# 0   Asia/Kuala_Lumpur  airport  OurAirports
# 1   Asia/Kuala_Lumpur  airport  OurAirports
# 2   Asia/Kuala_Lumpur  airport  OurAirports
# 3   Asia/Kuala_Lumpur  airport  OurAirports
# 4   Asia/Kuala_Lumpur  airport  OurAirports
# 5   Asia/Kuala_Lumpur  airport  OurAirports
# 6   Asia/Kuala_Lumpur  airport  OurAirports
# 7   Asia/Kuala_Lumpur  airport  OurAirports
# 8   Asia/Kuala_Lumpur  airport  OurAirports
# 9   Asia/Kuala_Lumpur  airport  OurAirports
# 10  Asia/Kuala_Lumpur  airport  OurAirports
# 11  Asia/Kuala_Lumpur  airport  OurAirports
# 12  Asia/Kuala_Lumpur  airport  OurAirports
# 13  Asia/Kuala_Lumpur  airport  OurAirports
# 14  Asia/Kuala_Lumpur  airport  OurAirports
# 15  Asia/Kuala_Lumpur  airport  OurAirports
# 16  Asia/Kuala_Lumpur  airport  OurAirports
# 17  Asia/Kuala_Lumpur  airport  OurAirports
# 18  Asia/Kuala_Lumpur  airport  OurAirports
# 19  Asia/Kuala_Lumpur  airport  OurAirports
# 20  Asia/Kuala_Lumpur  airport  OurAirports
# 21  Asia/Kuala_Lumpur  airport  OurAirports
# 22  Asia/Kuala_Lumpur  airport  OurAirports
# 23  Asia/Kuala_Lumpur  airport  OurAirports
# 24  Asia/Kuala_Lumpur  airport  OurAirports
# 25  Asia/Kuala_Lumpur  airport  OurAirports
# 26  Asia/Kuala_Lumpur  airport  OurAirports
# 27  Asia/Kuala_Lumpur  airport  OurAirports
# 28  Asia/Kuala_Lumpur  airport  OurAirports
# 29  Asia/Kuala_Lumpur  airport  OurAirports
# 30  Asia/Kuala_Lumpur  airport  OurAirports
# 31  Asia/Kuala_Lumpur  airport  OurAirports
# 32  Asia/Kuala_Lumpur  airport  OurAirports
# 33  Asia/Kuala_Lumpur  airport  OurAirports
# 34  Asia/Kuala_Lumpur  airport  OurAirports
# 35  Asia/Kuala_Lumpur  airport  OurAirports
# 36  Asia/Kuala_Lumpur  airport  OurAirports
# 37  Asia/Kuala_Lumpur  airport  OurAirports
# 38  Asia/Kuala_Lumpur  airport  OurAirports
# 39  Asia/Kuala_Lumpur  airport  OurAirports
# Total number of airport in Malaysia is 40
